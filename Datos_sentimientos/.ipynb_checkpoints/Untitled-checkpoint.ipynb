# %%
import pandas as pd
doc = pd.read_csv("meanAndStdev.csv", ",")

# %%
doc
# Out:
#                                        Cosa,c,o,s,a,s,s
# 0            población_N,1.8,2,2.6,0.4472,0.7071,0.5477
# 1               obra_N,2.2,2.4,2.4,0.4472,0.5477,0.8944
# 2                           dormir_V,3,1.4,3,0,0.8944,0
# 3                              dar_V,2.8,3,3,0.4472,0,0
# 4                  realizar_V,2.6,3,2.8,0.5477,0,0.4472
# 5                     haber_V,2,1.8,1.8,0,0.8367,0.4472
# 6                      amor_N,3,2.6,2.4,0,0.5477,0.8944
# 7                  aparecer_V,2,2.6,2.6,0,0.8944,0.5477
# 8             seguir_V,2.4,2.6,2.8,0.5477,0.8944,0.4472
# 9            especie_N,2.2,1.8,2.6,0.4472,0.4472,0.8944
# 10                           dejar_V,1.6,3,3,0.5477,0,0
# 11      nombre_N,2.1667,1.5,2.1667,0.4082,0.5477,0.7528
# 12                     solo_A,1.4,1.8,3,0.5477,0.4472,0
# 13                  corazón_N,2.8,2.4,3,0.4472,0.5477,0
# 14                          lograr_V,3,3,2.6,0,0,0.5477
# 15                 entender_V,3,2.8,2.6,0,0.4472,0.5477
# ...
